# %%
import yaml
import xarray as xr
# Out:
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %% [markdown]
# # Demonstrate the usage of intake-thredds

# %%
import intake
cat = intake.open_thredds_cat('http://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/catalog.xml')
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /opt/conda/envs/pyAODN/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-671c13779b03> in <module>
#       1 import intake
# ----> 2 cat = intake.open_thredds_cat('http://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/catalog.xml')
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/intake_thredds/cat.py in __init__(self, url, metadata)
#       8     def __init__(self, url, metadata=None):
#       9         self.url = url
# ---> 10         super().__init__(metadata)
#      11
#      12     def _load(self):
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/intake/catalog/base.py in __init__(self, *args, **kwargs)
#      96         self.updated = time.time()
#      97         self._entries = self._make_entries_container()
# ---> 98         self.force_reload()
#      99
#     100     def _make_entries_container(self):
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/intake/catalog/base.py in force_reload(self)
#     111     def force_reload(self):
#     112         """Imperative reload data now"""
# --> 113         self._load()
#     114         self.updated = time.time()
#     115
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/intake_thredds/cat.py in _load(self)
#      12     def _load(self):
#      13         from siphon.catalog import TDSCatalog
# ---> 14         self.cat = TDSCatalog(self.url)
#      15         self.name = self.cat.catalog_name
#      16
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/siphon/catalog.py in __init__(self, catalog_url)
#     254
#     255         # get catalog.xml file
# --> 256         resp = session.get(catalog_url)
#     257         resp.raise_for_status()
#     258
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# /opt/conda/envs/pyAODN/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /opt/conda/envs/pyAODN/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /opt/conda/envs/pyAODN/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /opt/conda/envs/pyAODN/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /opt/conda/envs/pyAODN/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     179
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#     183
#
# /opt/conda/envs/pyAODN/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Pick out a month - the \[''\]() syntax is a little ugly, but it works to return Intake catalogue objects and traverse the THREDDS server heirarchy

# %%
month=cat['2007']()['02']()
month.url
# Out:
# 'http://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/OC/gridded/aqua/P1D/2007/02/catalog.xml'

# %% [markdown]
# Print the files available within the month

# %%
for k in month:
    print(k)
# Out:
# A.P1D.20070201T000000Z.aust.K_490.nc
# A.P1D.20070201T000000Z.aust.chl_gsm.nc
# A.P1D.20070201T000000Z.aust.chl_oc3.nc
# A.P1D.20070201T000000Z.aust.dt.nc
# A.P1D.20070201T000000Z.aust.ipar.nc
# A.P1D.20070201T000000Z.aust.l2_flags.nc
# A.P1D.20070201T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070201T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070201T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070201T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070201T000000Z.aust.owtd.nc
# A.P1D.20070201T000000Z.aust.par.nc
# A.P1D.20070201T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070201T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070201T000000Z.aust.sst.nc
# A.P1D.20070201T000000Z.aust.sst_quality.nc
# A.P1D.20070202T000000Z.aust.K_490.nc
# A.P1D.20070202T000000Z.aust.chl_gsm.nc
# A.P1D.20070202T000000Z.aust.chl_oc3.nc
# A.P1D.20070202T000000Z.aust.dt.nc
# A.P1D.20070202T000000Z.aust.ipar.nc
# A.P1D.20070202T000000Z.aust.l2_flags.nc
# A.P1D.20070202T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20
000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070212T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070212T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070212T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070212T000000Z.aust.owtd.nc
# A.P1D.20070212T000000Z.aust.par.nc
# A.P1D.20070212T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070212T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070212T000000Z.aust.sst.nc
# A.P1D.20070212T000000Z.aust.sst_quality.nc
# A.P1D.20070213T000000Z.aust.K_490.nc
# A.P1D.20070213T000000Z.aust.chl_gsm.nc
# A.P1D.20070213T000000Z.aust.chl_oc3.nc
# A.P1D.20070213T000000Z.aust.dt.nc
# A.P1D.20070213T000000Z.aust.ipar.nc
# A.P1D.20070213T000000Z.aust.l2_flags.nc
# A.P1D.20070213T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070213T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070213T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070213T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070213T000000Z.aust.owtd.nc
# A.P1D.20070213T000000Z.aust.par.nc
# A.P1D.20070213T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070213T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070213T000000Z.aust.sst.nc
# A.P1D.20070213T000000Z.aust.sst_quality.nc
# A.P1D.20070214T000000Z.aust.K_490.nc
# A.P1D.20070214T000000Z.aust.chl_gsm.nc
# A.P1D.20070214T000000Z.aust.chl_oc3.nc
# A.P1D.20070214T000000Z.aust.dt.nc
# A.P1D.20070214T000000Z.aust.ipar.nc
# A.P1D.20070214T000000Z.aust.l2_flags.nc
# A.P1D.20070214T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070214T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070214T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070214T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070214T000000Z.aust.owtd.nc
# A.P1D.20070214T000000Z.aust.par.nc
# A.P1D.20070214T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070214T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070214T000000Z.aust.sst.nc
# A.P1D.20070214T000000Z.aust.sst_quality.nc
# A.P1D.20070215T000000Z.aust.K_490.nc
# A.P1D.20070215T000000Z.aust.chl_gsm.nc
# A.P1D.20070215T000000Z.aust.chl_oc3.nc
# A.P1D.20070215T000000Z.aust.dt.nc
# A.P1D.20070215T000000Z.aust.ipar.nc
# A.P1D.20070215T000000Z.aust.l2_flags.nc
# A.P1D.20070215T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070215T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070215T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070215T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070215T000000Z.aust.owtd.nc
# A.P1D.20070215T000000Z.aust.par.nc
# A.P1D.20070215T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070215T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070215T000000Z.aust.sst.nc
# A.P1D.20070215T000000Z.aust.sst_quality.nc
# A.P1D.20070216T000000Z.aust.K_490.nc
# A.P1D.20070216T000000Z.aust.chl_gsm.nc
# A.P1D.20070216T000000Z.aust.chl_oc3.nc
# A.P1D.20070216T000000Z.aust.dt.nc
# A.P1D.20070216T000000Z.aust.ipar.nc
# A.P1D.20070216T000000Z.aust.l2_flags.nc
# A.P1D.20070216T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070216T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070216T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070216T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070216T000000Z.aust.owtd.nc
# A.P1D.20070216T000000Z.aust.par.nc
# A.P1D.20070216T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070216T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070216T000000Z.aust.sst.nc
# A.P1D.20070216T000000Z.aust.sst_quality.nc
# A.P1D.20070217T000000Z.aust.K_490.nc
# A.P1D.20070217T000000Z.aust.chl_gsm.nc
# A.P1D.20070217T000000Z.aust.chl_oc3.nc
# A.P1D.20070217T000000Z.aust.dt.nc
# A.P1D.20070217T000000Z.aust.ipar.nc
# A.P1D.20070217T000000Z.aust.l2_flags.nc
# A.P1D.20070217T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070217T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070217T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070217T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070217T000000Z.aust.owtd.nc
# A.P1D.20070217T000000Z.aust.par.nc
# A.P1D.20070217T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070217T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070217T000000Z.aust.sst.nc
# A.P1D.20070217T000000Z.aust.sst_quality.nc
# A.P1D.20070218T000000Z.aust.K_490.nc
# A.P1D.20070218T000000Z.aust.chl_gsm.nc
# A.P1D.20070218T000000Z.aust.chl_oc3.nc
# A.P1D.20070218T000000Z.aust.dt.nc
# A.P1D.20070218T000000Z.aust.ipar.nc
# A.P1D.20070218T000000Z.aust.l2_flags.nc
# A.P1D.20070218T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070218T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070218T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070218T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070218T000000Z.aust.owtd.nc
# A.P1D.20070218T000000Z.aust.par.nc
# A.P1D.20070218T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070218T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070218T000000Z.aust.sst.nc
# A.P1D.20070218T000000Z.aust.sst_quality.nc
# A.P1D.20070219T000000Z.aust.K_490.nc
# A.P1D.20070219T000000Z.aust.chl_gsm.nc
# A.P1D.20070219T000000Z.aust.chl_oc3.nc
# A.P1D.20070219T000000Z.aust.dt.nc
# A.P1D.20070219T000000Z.aust.ipar.nc
# A.P1D.20070219T000000Z.aust.l2_flags.nc
# A.P1D.20070219T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070219T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070219T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070219T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070219T000000Z.aust.owtd.nc
# A.P1D.20070219T000000Z.aust.par.nc
# A.P1D.20070219T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070219T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070219T000000Z.aust.sst.nc
# A.P1D.20070219T000000Z.aust.sst_quality.nc
# A.P1D.20070220T000000Z.aust.K_490.nc
# A.P1D.20070220T000000Z.aust.chl_gsm.nc
# A.P1D.20070220T000000Z.aust.chl_oc3.nc
# A.P1D.20070220T000000Z.aust.dt.nc
# A.P1D.20070220T000000Z.aust.ipar.nc
# A.P1D.20070220T000000Z.aust.l2_flags.nc
# A.P1D.20070220T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070220T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070220T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070220T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070220T000000Z.aust.owtd.nc
# A.P1D.20070220T000000Z.aust.par.nc
# A.P1D.20070220T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070220T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070220T000000Z.aust.sst.nc
# A.P1D.20070220T000000Z.aust.sst_quality.nc
# A.P1D.20070221T000000Z.aust.K_490.nc
# A.P1D.20070221T000000Z.aust.chl_gsm.nc
# A.P1D.20070221T000000Z.aust.chl_oc3.nc
# A.P1D.20070221T000000Z.aust.dt.nc
# A.P1D.20070221T000000Z.aust.ipar.nc
# A.P1D.20070221T000000Z.aust.l2_flags.nc
# A.P1D.20070221T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070221T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070221T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070221T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070221T000000Z.aust.owtd.nc
# A.P1D.20070221T000000Z.aust.par.nc
# A.P1D.20070221T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070221T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070221T000000Z.aust.sst.nc
# A.P1D.20070221T000000Z.aust.sst_quality.nc
# A.P1D.20070222T000000Z.aust.K_490.nc
# A.P1D.20070222T000000Z.aust.chl_gsm.nc
# A.P1D.20070222T000000Z.aust.chl_oc3.nc
# A.P1D.20070222T000000Z.aust.dt.nc
# A.P1D.20070222T000000Z.aust.ipar.nc
# A.P1D.20070222T000000Z.aust.l2_flags.nc
# A.P1D.20070222T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070222T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070222T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070222T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070222T000000Z.aust.owtd.nc
# A.P1D.20070222T000000Z.aust.par.nc
# A.P1D.20070222T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070222T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070222T000000Z.aust.sst.nc
# A.P1D.20070222T000000Z.aust.sst_quality.nc
# A.P1D.20070223T000000Z.aust.K_490.nc
# A.P1D.20070223T000000Z.aust.chl_gsm.nc
# A.P1D.20070223T000000Z.aust.chl_oc3.nc
# A.P1D.20070223T000000Z.aust.dt.nc
# A.P1D.20070223T000000Z.aust.ipar.nc
# A.P1D.20070223T000000Z.aust.l2_flags.nc
# A.P1D.20070223T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070223T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070223T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070223T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070223T000000Z.aust.owtd.nc
# A.P1D.20070223T000000Z.aust.par.nc
# A.P1D.20070223T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070223T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070223T000000Z.aust.sst.nc
# A.P1D.20070223T000000Z.aust.sst_quality.nc
# A.P1D.20070224T000000Z.aust.K_490.nc
# A.P1D.20070224T000000Z.aust.chl_gsm.nc
# A.P1D.20070224T000000Z.aust.chl_oc3.nc
# A.P1D.20070224T000000Z.aust.dt.nc
# A.P1D.20070224T000000Z.aust.ipar.nc
# A.P1D.20070224T000000Z.aust.l2_flags.nc
# A.P1D.20070224T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070224T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070224T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070224T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070224T000000Z.aust.owtd.nc
# A.P1D.20070224T000000Z.aust.par.nc
# A.P1D.20070224T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070224T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070224T000000Z.aust.sst.nc
# A.P1D.20070224T000000Z.aust.sst_quality.nc
# A.P1D.20070225T000000Z.aust.K_490.nc
# A.P1D.20070225T000000Z.aust.chl_gsm.nc
# A.P1D.20070225T000000Z.aust.chl_oc3.nc
# A.P1D.20070225T000000Z.aust.dt.nc
# A.P1D.20070225T000000Z.aust.ipar.nc
# A.P1D.20070225T000000Z.aust.l2_flags.nc
# A.P1D.20070225T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070225T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070225T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070225T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070225T000000Z.aust.owtd.nc
# A.P1D.20070225T000000Z.aust.par.nc
# A.P1D.20070225T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070225T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070225T000000Z.aust.sst.nc
# A.P1D.20070225T000000Z.aust.sst_quality.nc
# A.P1D.20070226T000000Z.aust.K_490.nc
# A.P1D.20070226T000000Z.aust.chl_gsm.nc
# A.P1D.20070226T000000Z.aust.chl_oc3.nc
# A.P1D.20070226T000000Z.aust.dt.nc
# A.P1D.20070226T000000Z.aust.ipar.nc
# A.P1D.20070226T000000Z.aust.l2_flags.nc
# A.P1D.20070226T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070226T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070226T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070226T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070226T000000Z.aust.owtd.nc
# A.P1D.20070226T000000Z.aust.par.nc
# A.P1D.20070226T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070226T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070226T000000Z.aust.sst.nc
# A.P1D.20070226T000000Z.aust.sst_quality.nc
# A.P1D.20070227T000000Z.aust.K_490.nc
# A.P1D.20070227T000000Z.aust.chl_gsm.nc
# A.P1D.20070227T000000Z.aust.chl_oc3.nc
# A.P1D.20070227T000000Z.aust.dt.nc
# A.P1D.20070227T000000Z.aust.ipar.nc
# A.P1D.20070227T000000Z.aust.l2_flags.nc
# A.P1D.20070227T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070227T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070227T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070227T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070227T000000Z.aust.owtd.nc
# A.P1D.20070227T000000Z.aust.par.nc
# A.P1D.20070227T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070227T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070227T000000Z.aust.sst.nc
# A.P1D.20070227T000000Z.aust.sst_quality.nc
# A.P1D.20070228T000000Z.aust.K_490.nc
# A.P1D.20070228T000000Z.aust.chl_gsm.nc
# A.P1D.20070228T000000Z.aust.chl_oc3.nc
# A.P1D.20070228T000000Z.aust.dt.nc
# A.P1D.20070228T000000Z.aust.ipar.nc
# A.P1D.20070228T000000Z.aust.l2_flags.nc
# A.P1D.20070228T000000Z.aust.nanop_brewin2010at.nc
# A.P1D.20070228T000000Z.aust.nanop_brewin2012in.nc
# A.P1D.20070228T000000Z.aust.npp_vgpm_eppley_gsm.nc
# A.P1D.20070228T000000Z.aust.npp_vgpm_eppley_oc3.nc
# A.P1D.20070228T000000Z.aust.owtd.nc
# A.P1D.20070228T000000Z.aust.par.nc
# A.P1D.20070228T000000Z.aust.picop_brewin2010at.nc
# A.P1D.20070228T000000Z.aust.picop_brewin2012in.nc
# A.P1D.20070228T000000Z.aust.sst.nc
# A.P1D.20070228T000000Z.aust.sst_quality.nc

# %% [markdown]
# Open a NetCDF file from thredds using the intake catalog ".to_dask()" function - it actually returns an XArray Dataset, the naming is an overhang from intake being developed originally for use with dask.

# %%
ds=month['A.P1D.20070201T000000Z.aust.K_490.nc'].to_dask()
print(ds)
print('\n')
print(ds.K_490)
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 7001, longitude: 10001, time: 1)
# Coordinates:
#   * latitude   (latitude) float64 10.0 9.99 9.98 9.97 ... -59.98 -59.99 -60.0
#   * time       (time) datetime64[ns] 2007-02-01
#   * longitude  (longitude) float64 80.0 80.01 80.02 80.03 ... 180.0 180.0 180.0
# Data variables:
#     K_490      (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:                      CF-1.6
#     source_path:                      imos-srs/archive/oc/aqua/1d/v201508/200...
#     compliance_checker_version:       1.1.1 (79b23fe87f7e932974b93f7bdc1de29d...
#     compliance_checker_last_updated:  2016-01-21 01:31:49 UTC
#     history:                          File initialised at 2015-12-17T17:52:55...
#
#
# <xarray.DataArray 'K_490' (time: 1, latitude: 7001, longitude: 10001)>
# [70017001 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float64 10.0 9.99 9.98 9.97 ... -59.98 -59.99 -60.0
#   * time       (time) datetime64[ns] 2007-02-01
#   * longitude  (longitude) float64 80.0 80.01 80.02 80.03 ... 180.0 180.0 180.0
# Attributes:
#     flag_applied:  HISATZEN LAND CLDICE NAVFAIL
#     long_name:     Diffuse attenuation coefficient at 490 nm (OBPG)
#     units:         m^-1
#     _ChunkSizes:   [   1  856 1223]
